# %%
import pandas as pd

# %% [markdown]
# # Carga los archivos CSV

# %%
df1 = pd.read_csv('C:/Users/ASUS/Desktop/workshop3ETL/data/2015.csv')
df2 = pd.read_csv('C:/Users/ASUS/Desktop/workshop3ETL/data/2016.csv')
df3 = pd.read_csv('C:/Users/ASUS/Desktop/workshop3ETL/data/2017.csv')
df4 = pd.read_csv('C:/Users/ASUS/Desktop/workshop3ETL/data/2018.csv')
df5 = pd.read_csv('C:/Users/ASUS/Desktop/workshop3ETL/data/2019.csv')

# %% [markdown]
# # Diccionarios para renombrar columnas principales a nombres estandarizados

# %%
rename_df1 = {
    'Country': 'Country',
    'Region': 'Region',
    'Happiness Rank': 'Happiness_Rank',
    'Happiness Score': 'Happiness_Score',
    'Economy (GDP per Capita)': 'GDP_per_Capita',
    'Family': 'Social_Support',
    'Health (Life Expectancy)': 'Life_Expectancy',
    'Freedom': 'Freedom',
    'Generosity': 'Generosity',
    'Trust (Government Corruption)': 'Corruption_Perception',
    'Dystopia Residual': 'Dystopia_Residual',
    'Standard Error': 'Standard_Error' 
}

rename_df2 = {
    'Country': 'Country',
    'Region': 'Region',
    'Happiness Rank': 'Happiness_Rank',
    'Happiness Score': 'Happiness_Score',
    'Economy (GDP per Capita)': 'GDP_per_Capita',
    'Family': 'Social_Support',
    'Health (Life Expectancy)': 'Life_Expectancy',
    'Freedom': 'Freedom',
    'Generosity': 'Generosity',
    'Trust (Government Corruption)': 'Corruption_Perception',
    'Dystopia Residual': 'Dystopia_Residual',
    'Lower Confidence Interval': 'Lower_Confidence_Interval',  
    'Upper Confidence Interval': 'Upper_Confidence_Interval'  
}

rename_df3 = {
    'Country': 'Country',
    'Happiness.Rank': 'Happiness_Rank',
    'Happiness.Score': 'Happiness_Score',
    'Economy..GDP.per.Capita.': 'GDP_per_Capita',
    'Family': 'Social_Support',
    'Health..Life.Expectancy.': 'Life_Expectancy',
    'Freedom': 'Freedom',
    'Generosity': 'Generosity',
    'Trust..Government.Corruption.': 'Corruption_Perception',
    'Dystopia.Residual': 'Dystopia_Residual',
    'Whisker.high': 'Whisker_High',  
    'Whisker.low': 'Whisker_Low'  
}

rename_df4_df5 = {
    'Country or region': 'Country',
    'Overall rank': 'Happiness_Rank',
    'Score': 'Happiness_Score',
    'GDP per capita': 'GDP_per_Capita',
    'Social support': 'Social_Support',
    'Healthy life expectancy': 'Life_Expectancy',
    'Freedom to make life choices': 'Freedom',
    'Generosity': 'Generosity',
    'Perceptions of corruption': 'Corruption_Perception'
}

# %% [markdown]
# # Renombrar columnas

# %%
df1 = df1.rename(columns=rename_df1)
df2 = df2.rename(columns=rename_df2)
df3 = df3.rename(columns=rename_df3)
df4 = df4.rename(columns=rename_df4_df5)
df5 = df5.rename(columns=rename_df4_df5)

# %% [markdown]
# # Agregar columna 'Year'

# %%
df1['Year'] = 2015
df2['Year'] = 2016
df3['Year'] = 2017
df4['Year'] = 2018
df5['Year'] = 2019

# %% [markdown]
# # Concatenar todos los DataFrames sin eliminar columnas

# %%
df_combined = pd.concat([df1, df2, df3, df4, df5], ignore_index=True)

# %%
df_combined['id'] = range(1, len(df_combined) + 1)

# Reordenar columnas para que 'id' esté al principio
columnas = ['id'] + [col for col in df_combined.columns if col != 'id']
df_combined = df_combined[columnas]

# %% [markdown]
# # Verificar el resultado

# %%
print("Shape del DataFrame combinado:", df_combined.shape)
print("Columnas del DataFrame combinado:", df_combined.columns)
# Out:
# Shape del DataFrame combinado: (782, 18)
# Columnas del DataFrame combinado: Index(['id', 'Country', 'Region', 'Happiness_Rank', 'Happiness_Score',
#        'Standard_Error', 'GDP_per_Capita', 'Social_Support', 'Life_Expectancy',
#        'Freedom', 'Corruption_Perception', 'Generosity', 'Dystopia_Residual',
#        'Year', 'Lower_Confidence_Interval', 'Upper_Confidence_Interval',
#        'Whisker_High', 'Whisker_Low'],
#       dtype='object')

# %%
df_combined
# Out:
#       id                   Country          Region  Happiness_Rank  \
# 0      1               Switzerland  Western Europe               1
# 1      2                   Iceland  Western Europe               2
# 2      3                   Denmark  Western Europe               3
# 3      4                    Norway  Western Europe               4
# 4      5                    Canada   North America               5
# ..   ...                       ...             ...             ...
# 777  778                    Rwanda             NaN             152
# 778  779                  Tanzania             NaN             153
# 779  780               Afghanistan             NaN             154
# 780  781  Central African Republic             NaN             155
# 781  782               South Sudan             NaN             156
#
#      Happiness_Score  Standard_Error  GDP_per_Capita  Social_Support  \
# 0              7.587         0.03411         1.39651         1.34951
# ...

# %%
print("Valores nulos por columna:")
print(df_combined.isnull().sum())
# Out:
# Valores nulos por columna:
# id                             0
# Country                        0
# Region                       467
# Happiness_Rank                 0
# Happiness_Score                0
# Standard_Error               624
# GDP_per_Capita                 0
# Social_Support                 0
# Life_Expectancy                0
# Freedom                        0
# Corruption_Perception          1
# Generosity                     0
# Dystopia_Residual            312
# Year                           0
# Lower_Confidence_Interval    625
# Upper_Confidence_Interval    625
# Whisker_High                 627
# Whisker_Low                  627
# dtype: int64

# %% [markdown]
# # Guardar el resultado

# %%
df_combined.to_csv('C:/Users/ASUS/Desktop/workshop3ETL/data/df_combined.csv', index=False)
